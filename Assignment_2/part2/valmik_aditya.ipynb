# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, classification_report
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.utils import to_categorical
from imblearn.over_sampling import BorderlineSMOTE
import re
import nltk
from nltk.corpus import stopwords
import numpy as np

# Download stopwords
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))

def preprocess_text(text):
    text = text.lower()  # Convert to lowercase
    text = re.sub(r'[^a-zA-Z\s]', '', text)  # Remove special characters
    text = ' '.join([word for word in text.split() if word not in stop_words])  # Remove stopwords
    return text

# Load dataset
df = pd.read_csv("sentimentdataset.csv")
df = df[["Text", "Sentiment"]]
df["Sentiment"] = df["Sentiment"].str.strip()
df["ProcessedText"] = df["Text"].apply(preprocess_text)

# Encode labels
label_encoder = LabelEncoder()
df["SentimentEncoded"] = label_encoder.fit_transform(df["Sentiment"])

# Remove rare classes (classes with only 1 sample)
class_counts = df["SentimentEncoded"].value_counts()
rare_classes = class_counts[class_counts < 2].index
df = df[~df["SentimentEncoded"].isin(rare_classes)]

# Split dataset
X = df["ProcessedText"]
y = label_encoder.fit_transform(df["Sentiment"])  # Re-encode after removing rare classes

# Convert text to numerical features
vectorizer = TfidfVectorizer(ngram_range=(1,2), max_features=20000)  # Increase features for better representation
X_tfidf = vectorizer.fit_transform(X).toarray()

# Split BEFORE applying SMOTE
X_train, X_test, y_train, y_test = train_test_split(X_tfidf, y, test_size=0.2, random_state=42, stratify=y)

# Apply SMOTE only on training data
smote = BorderlineSMOTE(random_state=42, k_neighbors=1)
X_train, y_train = smote.fit_resample(X_train, y_train)

# Convert labels to categorical (AFTER applying SMOTE)
y_train_categorical = to_categorical(y_train)
y_test_categorical = to_categorical(y_test, num_classes=y_train_categorical.shape[1])  # Match train classes

# Train MLP Classifier with hyperparameter tuning
mlp_model = MLPClassifier(
    hidden_layer_sizes=(512, 256, 128),  # Deeper network
    activation='relu',
    solver='adam',
    alpha=0.0005,  # Lower regularization
    learning_rate='adaptive',
    max_iter=1500,  # More iterations for convergence
    early_stopping=True,
    random_state=42
)
mlp_model.fit(X_train, y_train)

# Predict with MLP
y_pred_mlp = mlp_model.predict(X_test)
mlp_accuracy = accuracy_score(y_test, y_pred_mlp)
print(f"MLP Classifier Accuracy: {mlp_accuracy:.4f}")
print("MLP Classification Report:\n", classification_report(y_test, y_pred_mlp))

# Train Deep Neural Network with improved regularization
num_classes = y_train_categorical.shape[1]  # Ensure correct output shape
model = Sequential([
    Dense(1024, activation='relu', input_shape=(X_train.shape[1],)),
    Dropout(0.4),
    Dense(512, activation='relu'),
    Dropout(0.4),
    Dense(256, activation='relu'),
    Dense(num_classes, activation='softmax')
])

# Compile DNN model with SGD + Momentum
model.compile(optimizer=SGD(learning_rate=0.01, momentum=0.9), loss='categorical_crossentropy', metrics=['accuracy'])

# Train DNN model with more epochs
model.fit(X_train, y_train_categorical, epochs=30, batch_size=64, validation_data=(X_test, y_test_categorical))

# Evaluate DNN model
loss, accuracy = model.evaluate(X_test, y_test_categorical)
print(f"Deep Neural Network Accuracy: {accuracy:.4f}")
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Valmik
# [nltk_data]     Belgaonkar\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# MLP Classifier Accuracy: 0.3053
# MLP Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            1       0
Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.0114 - loss: 4.7149 - val_accuracy: 0.0153 - val_loss: 4.7097
# Epoch 2/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.0158 - loss: 4.6916 - val_accuracy: 0.0076 - val_loss: 4.6994
# Epoch 3/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.0155 - loss: 4.6603 - val_accuracy: 0.0076 - val_loss: 4.6884
# Epoch 4/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.0125 - loss: 4.6257 - val_accuracy: 0.0076 - val_loss: 4.6763
# Epoch 5/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.0229 - loss: 4.5811 - val_accuracy: 0.0076 - val_loss: 4.6636
# Epoch 6/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.0479 - loss: 4.5314 - val_accuracy: 0.0076 - val_loss: 4.6554
# Epoch 7/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.1194 - loss: 4.4713 - val_accuracy: 0.0611 - val_loss: 4.6484
# Epoch 8/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.2721 - loss: 4.4113 - val_accuracy: 0.0611 - val_loss: 4.6370
# Epoch 9/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.3571 - loss: 4.3358 - val_accuracy: 0.1756 - val_loss: 4.6326
# Epoch 10/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.4276 - loss: 4.2545 - val_accuracy: 0.1450 - val_loss: 4.6167
# Epoch 11/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.5072 - loss: 4.1356 - val_accuracy: 0.0916 - val_loss: 4.6069
# Epoch 12/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.5525 - loss: 3.9701 - val_accuracy: 0.1985 - val_loss: 4.5684
# Epoch 13/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.6270 - loss: 3.7571 - val_accuracy: 0.1908 - val_loss: 4.5556
# Epoch 14/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.6471 - loss: 3.4821 - val_accuracy: 0.1450 - val_loss: 4.5272
# Epoch 15/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.6768 - loss: 3.0566 - val_accuracy: 0.2290 - val_loss: 4.3866
# Epoch 16/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.7432 - loss: 2.5634 - val_accuracy: 0.2901 - val_loss: 4.1873
# Epoch 17/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.7995 - loss: 2.0167 - val_accuracy: 0.2214 - val_loss: 3.9801
# Epoch 18/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.8434 - loss: 1.5313 - val_accuracy: 0.3130 - val_loss: 3.7879
# Epoch 19/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8787 - loss: 1.1668 - val_accuracy: 0.2137 - val_loss: 3.6130
# Epoch 20/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9030 - loss: 0.9117 - val_accuracy: 0.2290 - val_loss: 3.4120
# Epoch 21/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9031 - loss: 0.7568 - val_accuracy: 0.3664 - val_loss: 3.2135
# Epoch 22/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9257 - loss: 0.5768 - val_accuracy: 0.2595 - val_loss: 3.1359
# Epoch 23/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9322 - loss: 0.5095 - val_accuracy: 0.3359 - val_loss: 3.0022
# Epoch 24/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9440 - loss: 0.4064 - val_accuracy: 0.2672 - val_loss: 2.9412
# Epoch 25/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9412 - loss: 0.3904 - val_accuracy: 0.3511 - val_loss: 2.8390
# Epoch 26/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9464 - loss: 0.3402 - val_accuracy: 0.3206 - val_loss: 2.8089
# Epoch 27/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9538 - loss: 0.2843 - val_accuracy: 0.2977 - val_loss: 2.7883
# Epoch 28/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9567 - loss: 0.2375 - val_accuracy: 0.3130 - val_loss: 2.8063
# Epoch 29/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9633 - loss: 0.2317 - val_accuracy: 0.3740 - val_loss: 2.6933
# Epoch 30/30
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9638 - loss: 0.2215 - val_accuracy: 0.3359 - val_loss: 2.7295
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3398 - loss: 2.7213
# Deep Neural Network Accuracy: 0.3359

# %% [markdown]
# POSITIVE, NEGATIVE AND NEUTRAL

# %%
import pandas as pd
import numpy as np
import re
import nltk
from nltk.corpus import stopwords
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, classification_report
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.utils import to_categorical
from imblearn.over_sampling import BorderlineSMOTE
from sklearn.metrics.pairwise import cosine_similarity

# Download stopwords
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))

# Define sentiment categories mapping
sentiment_mapping = {
    "positive": ["happy", "joyful", "excellent", "great", "amazing", "good", "love"],
    "negative": ["bad", "terrible", "awful", "hate", "worst", "sad", "angry"],
    "neutral": ["okay", "fine", "average", "neutral", "fair", "moderate"]
}

# Convert words to TF-IDF vectors for similarity comparison
vectorizer = TfidfVectorizer()
all_words = list(set(sum(sentiment_mapping.values(), [])))
word_vectors = vectorizer.fit_transform(all_words)

# Function to classify sentiment labels using cosine similarity
def classify_sentiment(text):
    text_vector = vectorizer.transform([text])
    similarities = {category: np.mean(cosine_similarity(text_vector, 
                                vectorizer.transform(words))) for category, words in sentiment_mapping.items()}
    return max(similarities, key=similarities.get)  # Return category with highest similarity

# Preprocessing function
def preprocess_text(text):
    text = text.lower()
    text = re.sub(r'[^a-zA-Z\s]', '', text)
    text = ' '.join([word for word in text.split() if word not in stop_words])
    return text

# Load dataset
df = pd.read_csv("sentimentdataset.csv")
df = df[["Text", "Sentiment"]]
df["Sentiment"] = df["Sentiment"].str.strip()
df["ProcessedText"] = df["Text"].apply(preprocess_text)

df["SentimentCategory"] = df["Sentiment"].apply(classify_sentiment)

# Encode labels
label_encoder = LabelEncoder()
df["SentimentEncoded"] = label_encoder.fit_transform(df["SentimentCategory"])

# Split dataset
X = df["ProcessedText"]
y = df["SentimentEncoded"]

# Convert text to numerical features
vectorizer = TfidfVectorizer(ngram_range=(1,2), max_features=20000)
X_tfidf = vectorizer.fit_transform(X).toarray()

# Split BEFORE applying SMOTE
X_train, X_test, y_train, y_test = train_test_split(X_tfidf, y, test_size=0.2, random_state=42, stratify=y)

# Apply SMOTE only on training data
smote = BorderlineSMOTE(random_state=42, k_neighbors=1)
X_train, y_train = smote.fit_resample(X_train, y_train)

# Convert labels to categorical
y_train_categorical = to_categorical(y_train)
y_test_categorical = to_categorical(y_test, num_classes=y_train_categorical.shape[1])

# Train MLP Classifier
mlp_model = MLPClassifier(
    hidden_layer_sizes=(512, 256, 128),
    activation='relu',
    solver='adam',
    alpha=0.0005,
    learning_rate='adaptive',
    max_iter=1500,
    early_stopping=True,
    random_state=42
)
mlp_model.fit(X_train, y_train)

y_pred_mlp = mlp_model.predict(X_test)
mlp_accuracy = accuracy_score(y_test, y_pred_mlp)
print(f"MLP Classifier Accuracy: {mlp_accuracy:.4f}")
print("MLP Classification Report:\n", classification_report(y_test, y_pred_mlp))

# Train Deep Neural Network
num_classes = y_train_categorical.shape[1]
model = Sequential([
    Dense(1024, activation='relu', input_shape=(X_train.shape[1],)),
    Dropout(0.4),
    Dense(512, activation='relu'),
    Dropout(0.4),
    Dense(256, activation='relu'),
    Dense(num_classes, activation='softmax')
])

model.compile(optimizer=SGD(learning_rate=0.01, momentum=0.9), loss='categorical_crossentropy', metrics=['accuracy'])
model.fit(X_train, y_train_categorical, epochs=30, batch_size=64, validation_data=(X_test, y_test_categorical))

loss, accuracy = model.evaluate(X_test, y_test_categorical)
print(f"Deep Neural Network Accuracy: {accuracy:.4f}")
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Valmik
# [nltk_data]     Belgaonkar\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# MLP Classifier Accuracy: 0.9388
# MLP Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         4
#            1       0.00      0.00      0.00         4
#            2       0.95      0.99      0.97       139
#
#     accuracy                           0.94       147
#    macro avg       0.32      0.33      0.32       147
# weighted avg       0.89      0.94      0.92       147
#
# Epoch 1/30
# c:\Users\Valmik Belgaonkar\OneDrive\Desktop\IIITB Folder\6th Semester\Natural Language Processing\NLP_IIITB\nlpenv\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Valmik Belgaonkar\OneDrive\Desktop\IIITB Folder\6th Semester\Natural Language Processing\NLP_IIITB\nlpenv\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Valmik Belgaonkar\OneDrive\Desktop\IIITB Folder\6th Semester\Natural Language Processing\NLP_IIITB\nlpenv\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Valmik Belgaonkar\OneDrive\Desktop\IIITB Folder\6th Semester\Natural Language Processing\NLP_IIITB\nlpenv\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.3702 - loss: 1.0952 - val_accuracy: 0.0136 - val_loss: 1.1062
# Epoch 2/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.7216 - loss: 1.0728 - val_accuracy: 0.5646 - val_loss: 1.0893
# Epoch 3/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.8533 - loss: 1.0206 - val_accuracy: 0.7483 - val_loss: 1.0676
# Epoch 4/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.8961 - loss: 0.9018 - val_accuracy: 0.9184 - val_loss: 0.9953
# Epoch 5/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9430 - loss: 0.6583 - val_accuracy: 0.9388 - val_loss: 0.7333
# Epoch 6/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9920 - loss: 0.3751 - val_accuracy: 0.9456 - val_loss: 0.4221
# Epoch 7/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9905 - loss: 0.1953 - val_accuracy: 0.9456 - val_loss: 0.2673
# Epoch 8/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9934 - loss: 0.1029 - val_accuracy: 0.9456 - val_loss: 0.2372
# Epoch 9/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9960 - loss: 0.0643 - val_accuracy: 0.9456 - val_loss: 0.2297
# Epoch 10/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9948 - loss: 0.0498 - val_accuracy: 0.9456 - val_loss: 0.2316
# Epoch 11/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9947 - loss: 0.0419 - val_accuracy: 0.9456 - val_loss: 0.2359
# Epoch 12/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9934 - loss: 0.0366 - val_accuracy: 0.9456 - val_loss: 0.2353
# Epoch 13/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9958 - loss: 0.0263 - val_accuracy: 0.9456 - val_loss: 0.2377
# Epoch 14/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9960 - loss: 0.0217 - val_accuracy: 0.9456 - val_loss: 0.2406
# Epoch 15/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9941 - loss: 0.0273 - val_accuracy: 0.9456 - val_loss: 0.2394
# Epoch 16/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9940 - loss: 0.0221 - val_accuracy: 0.9456 - val_loss: 0.2459
# Epoch 17/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9952 - loss: 0.0155 - val_accuracy: 0.9456 - val_loss: 0.2408
# Epoch 18/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9962 - loss: 0.0150 - val_accuracy: 0.9456 - val_loss: 0.2426
# Epoch 19/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9972 - loss: 0.0138 - val_accuracy: 0.9456 - val_loss: 0.2524
# Epoch 20/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9995 - loss: 0.0098 - val_accuracy: 0.9456 - val_loss: 0.2537
# Epoch 21/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9997 - loss: 0.0090 - val_accuracy: 0.9456 - val_loss: 0.2633
# Epoch 22/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9983 - loss: 0.0087 - val_accuracy: 0.9456 - val_loss: 0.2501
# Epoch 23/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9999 - loss: 0.0067 - val_accuracy: 0.9456 - val_loss: 0.2649
# Epoch 24/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9987 - loss: 0.0072 - val_accuracy: 0.9456 - val_loss: 0.2637
# Epoch 25/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 1.0000 - loss: 0.0065 - val_accuracy: 0.9456 - val_loss: 0.2571
# Epoch 26/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 0.0057 - val_accuracy: 0.9456 - val_loss: 0.2612
# Epoch 27/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9986 - loss: 0.0067 - val_accuracy: 0.9456 - val_loss: 0.2622
# Epoch 28/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 1.0000 - loss: 0.0045 - val_accuracy: 0.9456 - val_loss: 0.2717
# Epoch 29/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9996 - loss: 0.0051 - val_accuracy: 0.9456 - val_loss: 0.2769
# Epoch 30/30
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.9456 - val_loss: 0.2797
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9350 - loss: 0.3720
# Deep Neural Network Accuracy: 0.9456
