# %%
import random
import math
import csv

# Activation functions
def sigmoid(x):
    return 1 / (1 + math.exp(-x))

def sigmoid_derivative(x):
    return x * (1 - x)

class MLP:
    def __init__(self, input_nodes, hidden_nodes, output_nodes):
        self.input_nodes = input_nodes
        self.hidden_nodes = hidden_nodes
        self.output_nodes = output_nodes
        
        # Initialize weights with small random values
        self.weights_input_hidden = [[random.uniform(-1, 1) for _ in range(hidden_nodes)] for _ in range(input_nodes)]
        self.weights_hidden_output = [random.uniform(-1, 1) for _ in range(hidden_nodes)]
        
        # Initialize biases
        self.bias_hidden = [random.uniform(-1, 1) for _ in range(hidden_nodes)]
        self.bias_output = random.uniform(-1, 1)
    
    def forward(self, inputs):
        # Hidden layer calculations
        self.hidden_layer = []
        for i in range(self.hidden_nodes):
            weighted_sum = sum(inputs[j] * self.weights_input_hidden[j][i] for j in range(self.input_nodes)) + self.bias_hidden[i]
            self.hidden_layer.append(sigmoid(weighted_sum))
        
        # Output layer calculation
        output_weighted_sum = sum(self.hidden_layer[i] * self.weights_hidden_output[i] for i in range(self.hidden_nodes)) + self.bias_output
        self.output = sigmoid(output_weighted_sum)
        return self.output
    
    def backward(self, inputs, expected_output, learning_rate):
        # Calculate output layer error
        output_error = expected_output - self.output
        output_delta = output_error * sigmoid_derivative(self.output)
        
        # Calculate hidden layer errors
        hidden_errors = [self.weights_hidden_output[i] * output_delta for i in range(self.hidden_nodes)]
        hidden_deltas = [hidden_errors[i] * sigmoid_derivative(self.hidden_layer[i]) for i in range(self.hidden_nodes)]
        
        # Update weights and biases
        for i in range(self.hidden_nodes):
            self.weights_hidden_output[i] += learning_rate * output_delta * self.hidden_layer[i]
        self.bias_output += learning_rate * output_delta
        
        for i in range(self.input_nodes):
            for j in range(self.hidden_nodes):
                self.weights_input_hidden[i][j] += learning_rate * hidden_deltas[j] * inputs[i]
        for i in range(self.hidden_nodes):
            self.bias_hidden[i] += learning_rate * hidden_deltas[i]
    
    def train(self, dataset, epochs, learning_rate):
        for epoch in range(epochs):
            total_error = 0
            for data in dataset:
                inputs = [data[0], data[1]]
                expected_output = data[2]
                
                self.forward(inputs)
                self.backward(inputs, expected_output, learning_rate)
                
                total_error += (expected_output - self.output) ** 2
            
            if epoch % 1000 == 0:
                print(f"Epoch {epoch}, Error: {total_error}")
    
    def predict(self, inputs):
        output = self.forward(inputs)
        return 1 if output > 0.5 else 0

# Load dataset from CSV
def load_dataset(filename):
    dataset = []
    with open(filename, 'r') as file:
        reader = csv.reader(file)
        next(reader)  # Skip header
        for row in reader:
            dataset.append([float(row[1]), float(row[2]), float(row[3])])
    return dataset

# Split dataset into training and validation sets
def split_dataset(dataset, train_ratio=0.8):
    random.shuffle(dataset)
    train_size = int(len(dataset) * train_ratio)
    return dataset[:train_size], dataset[train_size:]

# Load and split the dataset
dataset = load_dataset("xor.csv")
train_data, validation_data = split_dataset(dataset)

# Initialize and train the MLP
mlp = MLP(input_nodes=2, hidden_nodes=4, output_nodes=1)
mlp.train(train_data, epochs=10000, learning_rate=0.1)

# Testing the MLP on validation data
correct_predictions = 0
print("\nValidation Results:")
for data in validation_data:
    inputs = [data[0], data[1]]
    prediction = mlp.predict(inputs)
    actual_label = int(data[2])
    print(f"Input: {inputs}, Predicted Label: {prediction}, Actual Label: {actual_label}")
    if prediction == actual_label:
        correct_predictions += 1

# Calculate and print validation accuracy
accuracy = (correct_predictions / len(validation_data)) * 100
print(f"\nValidation Accuracy: {accuracy:.2f}%")
# Out:
# Epoch 0, Error: 203.96467966488396
# Epoch 1000, Error: 10.703788106261044
# Epoch 2000, Error: 8.563550743707953
# Epoch 3000, Error: 7.711455251659272
# Epoch 4000, Error: 7.204538242419433
# Epoch 5000, Error: 6.853961746509258
# Epoch 6000, Error: 6.591532487163072
# Epoch 7000, Error: 6.385352092538099
# Epoch 8000, Error: 6.21772548167116
# Epoch 9000, Error: 6.077669252456801
#
# Validation Results:
# Input: [0.4287187330756249, 0.5856174890773638], Predicted Label: 1, Actual Label: 1
# Input: [0.980305930913831, 0.5730905169394434], Predicted Label: 0, Actual Label: 0
# Input: [0.8231804185071068, 0.12470051706005925], Predicted Label: 1, Actual Label: 1
# Input: [0.3361808581463472, 0.36027277314075423], Predicted Label: 0, Actual Label: 0
# Input: [0.8525184161505062, 0.9528055463471943], Predicted Label: 0, Actual Label: 0
# Input: [0.0071557175961621255, 0.11351974824680489], Predicted Label: 0, Actual Label: 0
# Input: [0.19134235993999116, 0.27442640921133543], Predicted Label: 0, Actual Label: 0
# Input: [0.9673950643506184, 0.32111768173072736], Predicted Label: 1, Actual Label: 1
# Input: [0.7354197070851339, 0.06618539871597201], Predicted Label: 1, Actual Label: 1
# Input: [0.253480383850892, 0.8395761584129657], Predicted Label: 1, Actual Label: 1
# Input: [0.7976483806967425, 0.8655302336674093], Predicted Label: 0, Actual Label: 0
# Input: [0.9108476024819065, 0.9459019087301508], Predicted Label: 0, Actual Label: 0
# Input: [0.05700502235151139, 0.44865938537261474], Predicted Label: 0, Actual Label: 0
# Input: [0.1257223250291849, 0.28497758068433326], Predicted Label: 0, Actual Label: 0
# Input: [0.6699812523621622, 0.24899561198072723], Predicted Label: 1, Actual Label: 1
# Input: [0.28846163539828146, 0.14564096203313975], Predicted Label: 0, Actual Label: 0
# Input: [0.7548145071449087, 0.8797072220473667], Predicted Label: 0, Actual Label: 0
# Input: [0.5384131994481405, 0.5780857305976559], Predicted Label: 0, Actual Label: 0
# Input: [0.005608672405194304, 0.3446283943687485], Predicted Label: 0, Actual Label: 0
# Input: [0.5749394091803829, 0.6960474245592485], Predicted Label: 0, Actual Label: 0
# Input: [0.5160135232569154, 0.2529124983351162], Predicted Label: 1, Actual Label: 1
# Input: [0.3014130117137584, 0.2339334980181732], Predicted Label: 0, Actual Label: 0
# Input: [0.9918595105397917, 0.7010350289845735], Predicted Label: 0, Actual Label: 0
# Input: [0.8489267906414597, 0.37710224296299877], Predicted Label: 1, Actual Label: 1
# Input: [0.08612674788445851, 0.08122713962891015], Predicted Label: 0, Actual Label: 0
# Input: [0.582653922050339, 0.0007651499302185338], Predicted Label: 1, Actual Label: 1
# Input: [0.05313904166676281, 0.23312719135908755], Predicted Label: 0, Actual Label: 0
# Input: [0.04959840504441304, 0.37395927303858606], Predicted Label: 0, Actual Label: 0
# Input: [0.8998041278482833, 0.9730207858141028], Predicted Label: 0, Actual Label: 0
# Input: [0.9227386258361728, 0.8799078035146317], Predicted Label: 0, Actual Label: 0
# Input: [0.8774170218035833, 0.992707619817796], Predicted Label: 0, Actual Label: 0
# Input: [0.35080130983628516, 0.6118898345325509], Predicted Label: 1, Actual Label: 1
# Input: [0.0682167029327968, 0.10970647616638274], Predicted Label: 0, Actual Label: 0
# Input: [0.4191697029617954, 0.6882890619342474], Predicted Label: 1, Actual Label: 1
# Input: [0.29924643196429646, 0.47958699517539094], Predicted Label: 0, Actual Label: 0
# Input: [0.06396463141475844, 0.19442023731473462], Predicted Label: 0, Actual Label: 0
# Input: [0.9996291122311298, 0.8508225724086292], Predicted Label: 0, Actual Label: 0
# Input: [0.04185703514216044, 0.8143959067407209], Predicted Label: 1, Actual Label: 1
# Input: [0.28712774554626275, 0.614718994130492], Predicted Label: 1, Actual Label: 1
# Input: [0.5760341888351073, 0.6871444296568735], Predicted Label: 0, Actual Label: 0
# Input: [0.4310445485631744, 0.07851012243668448], Predicted Label: 0, Actual Label: 0
# Input: [0.3031502964989608, 0.16142899014877532], Predicted Label: 0, Actual Label: 0
# Input: [0.6686695950573568, 0.20852580934264686], Predicted Label: 1, Actual Label: 1
# Input: [0.22609496622037517, 0.011279499094590861], Predicted Label: 0, Actual Label: 0
# Input: [0.912722367924762, 0.6169447478135517], Predicted Label: 0, Actual Label: 0
# Input: [0.6021017019434303, 0.026772436605053518], Predicted Label: 1, Actual Label: 1
# Input: [0.9509585998446237, 0.1224508947929705], Predicted Label: 1, Actual Label: 1
# Input: [0.9684297626174454, 0.3562118715944445], Predicted Label: 1, Actual Label: 1
# Input: [0.0761125637809375, 0.9062133520245259], Predicted Label: 1, Actual Label: 1
# Input: [0.5033683600165116, 0.9118398130709655], Predicted Label: 0, Actual Label: 0
# Input: [0.324073182990058, 0.8954361500493608], Predicted Label: 1, Actual Label: 1
# Input: [0.16379227051215245, 0.597522919050413], Predicted Label: 1, Actual Label: 1
# Input: [0.04469447800969789, 0.9834306362191154], Predicted Label: 1, Actual Label: 1
# Input: [0.10015572132328276, 0.4475924587996932], Predicted Label: 0, Actual Label: 0
# Input: [0.3263274418554513, 0.473272316024216], Predicted Label: 0, Actual Label: 0
# Input: [0.5108526012191665, 0.12098482454168502], Predicted Label: 1, Actual Label: 1
# Input: [0.9236747424187922, 0.4259809099867449], Predicted Label: 1, Actual Label: 1
# Input: [0.7082198420767316, 0.7546127522584483], Predicted Label: 0, Actual Label: 0
# Input: [0.48737217765802443, 0.4324611467290746], Predicted Label: 0, Actual Label: 0
# Input: [0.19170247142365077, 0.2848424660111303], Predicted Label: 0, Actual Label: 0
# Input: [0.23521364653957744, 0.0689220630265453], Predicted Label: 0, Actual Label: 0
# Input: [0.24765083783892883, 0.08004185683241383], Predicted Label: 0, Actual Label: 0
# Input: [0.27131932377002527, 0.814184735346855], Predicted Label: 1, Actual Label: 1
# Input: [0.6270597532883296, 0.5974079184451977], Predicted Label: 0, Actual Label: 0
# Input: [0.597076107015113, 0.9422884243385947], Predicted Label: 0, Actual Label: 0
# Input: [0.5979777382041558, 0.2811473290101774], Predicted Label: 1, Actual Label: 1
# Input: [0.5418982310420943, 0.6197449854669161], Predicted Label: 0, Actual Label: 0
# Input: [0.9061617038726966, 0.12187366552671142], Predicted Label: 1, Actual Label: 1
# Input: [0.3821595686265511, 0.05358935580199192], Predicted Label: 0, Actual Label: 0
# Input: [0.09203643530369093, 0.9470457121837685], Predicted Label: 1, Actual Label: 1
# Input: [0.7063516005543236, 0.4306825359493451], Predicted Label: 1, Actual Label: 1
# Input: [0.22177117722394674, 0.7387885379590293], Predicted Label: 1, Actual Label: 1
# Input: [0.0027897897067156174, 0.4163736557918129], Predicted Label: 0, Actual Label: 0
# Input: [0.4324809637546855, 0.6887580757662473], Predicted Label: 1, Actual Label: 1
# Input: [0.08840370534788672, 0.7047746033264453], Predicted Label: 1, Actual Label: 1
# Input: [0.903545761477365, 0.688812592528816], Predicted Label: 0, Actual Label: 0
# Input: [0.25302486439219884, 0.723892659253941], Predicted Label: 1, Actual Label: 1
# Input: [0.22134397296152336, 0.9089245222467244], Predicted Label: 1, Actual Label: 1
# Input: [0.8468560109039887, 0.8644732350458368], Predicted Label: 0, Actual Label: 0
# Input: [0.2043177942080039, 0.0017070536786072399], Predicted Label: 0, Actual Label: 0
# Input: [0.1209689881786995, 0.10123562182767598], Predicted Label: 0, Actual Label: 0
# Input: [0.2790589011662431, 0.23381483932998293], Predicted Label: 0, Actual Label: 0
# Input: [0.0065597497359138335, 0.007309102203111706], Predicted Label: 0, Actual Label: 0
# Input: [0.6646668011613708, 0.3537081123770673], Predicted Label: 1, Actual Label: 1
# Input: [0.6264662834341711, 0.9855774800321783], Predicted Label: 0, Actual Label: 0
# Input: [0.7251299666145711, 0.1383516173782554], Predicted Label: 1, Actual Label: 1
# Input: [0.11354186168270891, 0.5953920653922091], Predicted Label: 1, Actual Label: 1
# Input: [0.8128127502128712, 0.029137940517674266], Predicted Label: 1, Actual Label: 1
# Input: [0.9376851772108887, 0.03403787587885804], Predicted Label: 1, Actual Label: 1
# Input: [0.5724888413754727, 0.2444024170792689], Predicted Label: 1, Actual Label: 1
# Input: [0.22625992667056777, 0.10245880385358386], Predicted Label: 0, Actual Label: 0
# Input: [0.9717666328166026, 0.6784205594045722], Predicted Label: 0, Actual Label: 0
# Input: [0.4098746024304827, 0.25188890840827716], Predicted Label: 0, Actual Label: 0
# Input: [0.23931327355029425, 0.16179002141421128], Predicted Label: 0, Actual Label: 0
# Input: [0.3605477557212842, 0.13797437627487513], Predicted Label: 0, Actual Label: 0
# Input: [0.41137864391225465, 0.07592919317940017], Predicted Label: 0, Actual Label: 0
# Input: [0.3978146696558545, 0.9408235670887449], Predicted Label: 1, Actual Label: 1
# Input: [0.37616501132847957, 0.20268440535638071], Predicted Label: 0, Actual Label: 0
# Input: [0.27817174705110304, 0.5689835001184147], Predicted Label: 1, Actual Label: 1
# Input: [0.6851156608730111, 0.29416979543626626], Predicted Label: 1, Actual Label: 1
# Input: [0.25037475454921343, 0.5180867807612812], Predicted Label: 1, Actual Label: 1
# Input: [0.6975957777461906, 0.7616876242982502], Predicted Label: 0, Actual Label: 0
# Input: [0.7378350767224604, 0.9469329348930806], Predicted Label: 0, Actual Label: 0
# Input: [0.17560244899505362, 0.1725451438141241], Predicted Label: 0, Actual Label: 0
# Input: [0.9348642871035271, 0.5838439046879025], Predicted Label: 0, Actual Label: 0
# Input: [0.9765784527231127, 0.0627024096470783], Predicted Label: 1, Actual Label: 1
# Input: [0.7828418847028482, 0.42208782946462475], Predicted Label: 1, Actual Label: 1
# Input: [0.2617571047370167, 0.4749041241819097], Predicted Label: 0, Actual Label: 0
# Input: [0.882548890397737, 0.4890224125051299], Predicted Label: 1, Actual Label: 1
# Input: [0.9214431711770129, 0.9319377442537471], Predicted Label: 0, Actual Label: 0
# Input: [0.5136203063234606, 0.037832478135398695], Predicted Label: 1, Actual Label: 1
# Input: [0.5159129763059597, 0.8738520699179639], Predicted Label: 0, Actual Label: 0
# Input: [0.09368728612575233, 0.2441334951970332], Predicted Label: 0, Actual Label: 0
# Input: [0.8687150502604878, 0.1488216358726393], Predicted Label: 1, Actual Label: 1
# Input: [0.5160172321514214, 0.7167297198468874], Predicted Label: 0, Actual Label: 0
# Input: [0.693376455494592, 0.8214774489572171], Predicted Label: 0, Actual Label: 0
# Input: [0.8339068062971937, 0.3593693556708563], Predicted Label: 1, Actual Label: 1
# Input: [0.8076547819036618, 0.3141777952190151], Predicted Label: 1, Actual Label: 1
# Input: [0.16799172229376252, 0.24282944313325205], Predicted Label: 0, Actual Label: 0
# Input: [0.6582188062814938, 0.03312777631969033], Predicted Label: 1, Actual Label: 1
# Input: [0.7147170950828853, 0.2717533735823953], Predicted Label: 1, Actual Label: 1
# Input: [0.05193518914180323, 0.34700928975799405], Predicted Label: 0, Actual Label: 0
# Input: [0.3318466886071559, 0.6314396466074235], Predicted Label: 1, Actual Label: 1
# Input: [0.1590211783294354, 0.4714152317108882], Predicted Label: 0, Actual Label: 0
# Input: [0.7947599430869967, 0.8977092663801856], Predicted Label: 0, Actual Label: 0
# Input: [0.7067090288094593, 0.7893287690766213], Predicted Label: 0, Actual Label: 0
# Input: [0.2045238450751461, 0.4303016302218755], Predicted Label: 0, Actual Label: 0
# Input: [0.19275389492850126, 0.01130700843328969], Predicted Label: 0, Actual Label: 0
# Input: [0.08028684654492874, 0.4544911369922697], Predicted Label: 0, Actual Label: 0
# Input: [0.349683425370183, 0.9459952198095716], Predicted Label: 1, Actual Label: 1
# Input: [0.17932039955654483, 0.7046181167616841], Predicted Label: 1, Actual Label: 1
# Input: [0.6818010613199048, 0.6871731844009703], Predicted Label: 0, Actual Label: 0
# Input: [0.023698609846884988, 0.5306257043661828], Predicted Label: 1, Actual Label: 1
# Input: [0.20148465596922066, 0.6631172886008199], Predicted Label: 1, Actual Label: 1
# Input: [0.1788305375438361, 0.0878508281257156], Predicted Label: 0, Actual Label: 0
# Input: [0.5068294374410599, 0.5949729342335033], Predicted Label: 1, Actual Label: 0
# Input: [0.5440171236886162, 0.49181987939592764], Predicted Label: 1, Actual Label: 1
# Input: [0.4398155291496111, 0.7574376044111328], Predicted Label: 1, Actual Label: 1
# Input: [0.23082354350245182, 0.6106273342761244], Predicted Label: 1, Actual Label: 1
# Input: [0.8360163308655262, 0.07538516558436409], Predicted Label: 1, Actual Label: 1
# Input: [0.16777545923278608, 0.6132625049010902], Predicted Label: 1, Actual Label: 1
# Input: [0.21469641850199261, 0.7029736004028553], Predicted Label: 1, Actual Label: 1
# Input: [0.6517395780298567, 0.5630685145798879], Predicted Label: 0, Actual Label: 0
# Input: [0.22141510141961512, 0.7719936235273388], Predicted Label: 1, Actual Label: 1
# Input: [0.3500321924220564, 0.2874370624431894], Predicted Label: 0, Actual Label: 0
# Input: [0.197145159993937, 0.7098426287446331], Predicted Label: 1, Actual Label: 1
# Input: [0.8343993346048961, 0.17479046424763411], Predicted Label: 1, Actual Label: 1
# Input: [0.3091080695991204, 0.7489337135701983], Predicted Label: 1, Actual Label: 1
# Input: [0.1835662527599599, 0.6145759049756674], Predicted Label: 1, Actual Label: 1
# Input: [0.8595251350487481, 0.6186278699777881], Predicted Label: 0, Actual Label: 0
# Input: [0.11656804976774005, 0.016554643425141014], Predicted Label: 0, Actual Label: 0
# Input: [0.4870389282228325, 0.1791223418228594], Predicted Label: 0, Actual Label: 0
# Input: [0.878872166310601, 0.5123320030889011], Predicted Label: 0, Actual Label: 0
# Input: [0.3699883408176322, 0.5122048736132487], Predicted Label: 1, Actual Label: 1
# Input: [0.88097149894654, 0.29323256661010594], Predicted Label: 1, Actual Label: 1
# Input: [0.9703711771942926, 0.6802975935110461], Predicted Label: 0, Actual Label: 0
# Input: [0.38632468680465976, 0.6474648775024517], Predicted Label: 1, Actual Label: 1
# Input: [0.8233752809409765, 0.2256838741595401], Predicted Label: 1, Actual Label: 1
# Input: [0.5167060367996019, 0.1303740520859502], Predicted Label: 1, Actual Label: 1
# Input: [0.5230798516014286, 0.3322059085986042], Predicted Label: 1, Actual Label: 1
# Input: [0.709798243471546, 0.831925051010975], Predicted Label: 0, Actual Label: 0
# Input: [0.2323995932006776, 0.9320700663564332], Predicted Label: 1, Actual Label: 1
# Input: [0.8546209558421084, 0.7811866621924899], Predicted Label: 0, Actual Label: 0
# Input: [0.9882764695516224, 0.4251702349896975], Predicted Label: 1, Actual Label: 1
# Input: [0.817382092103266, 0.5507588998430024], Predicted Label: 0, Actual Label: 0
# Input: [0.6493302818866863, 0.639300881229208], Predicted Label: 0, Actual Label: 0
# Input: [0.05836037578413056, 0.30558476134103335], Predicted Label: 0, Actual Label: 0
# Input: [0.11255791352010397, 0.17019438382556817], Predicted Label: 0, Actual Label: 0
# Input: [0.6693732284000736, 0.18048488791567963], Predicted Label: 1, Actual Label: 1
# Input: [0.17877662266249933, 0.4965516767348678], Predicted Label: 0, Actual Label: 0
# Input: [0.9095465591438381, 0.8020513671736675], Predicted Label: 0, Actual Label: 0
# Input: [0.9997603039841823, 0.5624840555783193], Predicted Label: 0, Actual Label: 0
# Input: [0.4551166426403345, 0.5318030735493726], Predicted Label: 1, Actual Label: 1
# Input: [0.6968791435350152, 0.534914690284441], Predicted Label: 0, Actual Label: 0
# Input: [0.42098779252367696, 0.9765549627404138], Predicted Label: 1, Actual Label: 1
# Input: [0.8139974281274472, 0.1084468861950042], Predicted Label: 1, Actual Label: 1
# Input: [0.06251397837276473, 0.3567007034934366], Predicted Label: 0, Actual Label: 0
# Input: [0.8667019904281847, 0.6407161545089697], Predicted Label: 0, Actual Label: 0
# Input: [0.6109587681225145, 0.8073837764223053], Predicted Label: 0, Actual Label: 0
# Input: [0.962670000649015, 0.6715064908422427], Predicted Label: 0, Actual Label: 0
# Input: [0.422122296766535, 0.9132403159860005], Predicted Label: 1, Actual Label: 1
# Input: [0.21501741415269682, 0.6996855195436118], Predicted Label: 1, Actual Label: 1
# Input: [0.8892844731014669, 0.9292334227456684], Predicted Label: 0, Actual Label: 0
# Input: [0.6751897184693061, 0.07202079020151436], Predicted Label: 1, Actual Label: 1
# Input: [0.08853114703325066, 0.6973803570714348], Predicted Label: 1, Actual Label: 1
# Input: [0.47504530688629387, 0.22633764097498027], Predicted Label: 0, Actual Label: 0
# Input: [0.8199602263493804, 0.8766087745086916], Predicted Label: 0, Actual Label: 0
# Input: [0.15951195609656826, 0.3215870814854185], Predicted Label: 0, Actual Label: 0
# Input: [0.4720579104430195, 0.4333863839862065], Predicted Label: 0, Actual Label: 0
# Input: [0.4071887124824967, 0.7240102362292286], Predicted Label: 1, Actual Label: 1
# Input: [0.011437677153274206, 0.05172854879284017], Predicted Label: 0, Actual Label: 0
# Input: [0.9861370724869245, 0.38879379747330506], Predicted Label: 1, Actual Label: 1
# Input: [0.721595322674049, 0.4312920703467548], Predicted Label: 1, Actual Label: 1
# Input: [0.09544971893828769, 0.5139627824542539], Predicted Label: 1, Actual Label: 1
# Input: [0.042482042942819986, 0.9671263898509498], Predicted Label: 1, Actual Label: 1
# Input: [0.49396179246545274, 0.6335341622254594], Predicted Label: 1, Actual Label: 1
# Input: [0.49294691467712515, 0.9784918679265469], Predicted Label: 1, Actual Label: 1
# Input: [0.11872150857597646, 0.7048636913106845], Predicted Label: 1, Actual Label: 1
# Input: [0.004607972967446805, 0.8768135541502445], Predicted Label: 1, Actual Label: 1
# Input: [0.7561042130398639, 0.7841194443638833], Predicted Label: 0, Actual Label: 0
#
# Validation Accuracy: 99.50%
